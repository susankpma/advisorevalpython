# %% [markdown]
# # Step 2: Generate summary data for single advisor
#
# Generate summary data as html tables for single advisor.
# * create summary data for each section (i.e., pivot table of responses)
# * get comments
# * split topics (comma-separated responses)
# * combine summary data

# %% [markdown]
# ## 1. Set variables

# %%
# files to open
access_eval = 'ACCESS Advising Evaluation (Responses).xlsx'
soc_eval = 'SOC Advising (Responses).xlsx'

# time variables
filter_year = 2025
filter_month = 11

# questions to remove
# November 2025 survey questions changed and Google Sheets was reindexed.
# Starting December 2025, questions do not need to be removed.

# text to remove from each question
eval_remove_text = ['Please evaluate your advising session',
                    'Please evaluate the advisor',
                    'Overall advising appointment',
                    '[',
                    ']',
                    '.',
                    ':',
                    'Check all that apply.']

# text to replace
comments_replace = ['Please feel free to make additional comments of the above questions', 'Additional comments?']

# Likert scale values
likert_scale_access1 = ['Strongly Agree (5)', 'Agree (4)', 'Neutral (3)', 'Disagree (2)', 'Strongly Disagree (1)', 'Not Applicable (0)', 'No Response']
likert_scale_access2 = ['Excellent (5)', 'Good (4)', 'Average (3)', 'Fair (2)', 'Poor (1)', 'No Response']
likert_scale_soc1 = ['Strongly agree', 'Agree', 'Neutral', 'Disagree', 'Strongly Disagree', 'No Response']
likert_scale_soc2 = ['Excellent', 'Good', 'Average', 'Fair', 'Poor', 'No Response']

# meeting types
meeting_types = ['Via email', 'Via phone', 'Via Zoom', 'In person']

# %% [markdown]
# ## 2. Load and clean data (from Step 1)

# %%
# load libraries
import pandas as pd
from IPython.display import display, HTML  # library to display html in notebook

# %%
# load data
access_df = pd.read_excel(access_eval)
soc_df = pd.read_excel(soc_eval)

# %%
# clean data
def clean_data(df, text_remove_list, text_replace_list):
    for i in text_remove_list:
        df.columns = df.columns.str.replace(i, '')

    for i in text_replace_list:
        df.columns = df.columns.str.replace(i, 'Comments')

    df.columns = df.columns.str.strip()

    df = df[df['Timestamp'].dt.year == filter_year]
    df = df[df['Timestamp'].dt.month == filter_month]

    df = df.fillna('No Response')
    
    return df

# clean data
access_df = clean_data(access_df, eval_remove_text, comments_replace)
soc_df = clean_data(soc_df, eval_remove_text, comments_replace)

# %%
# check data
soc_df
# Out:
#                   Timestamp        Advisor  \
# 850 2025-11-05 09:13:29.903  Barbara Joyce
# 851 2025-11-22 10:23:13.182   Dawn Nishida
# 852 2025-11-24 14:50:37.496  Barbara Joyce
# 853 2025-11-25 00:18:38.081  Barbara Joyce
# 854 2025-11-27 10:58:45.681  Barbara Joyce
#
#     How did you meet with your advisor?  \
# 850                            Via Zoom
# 851                            Via Zoom
# 852                            Via Zoom
# 853                            Via Zoom
# 854                            Via Zoom
#
#     What did your meeting include?  Check all that apply  \
# 850  Internships, Career information, Academic Plan...
# 851  Registration Questions, Academic Planning, BAM...
# 852                             Registration Questions
# 853  Registration Questions, Graduation, Advice abo...
# 854  Registration Questions, Mandatory Advising, Ac...
#
#     I was satisfied with how my advisor handled my questions  \
# 850                                     Strongly agree
# 851                                     Strongly agree
# 852                                     Strongly agree
# 853                                     Strongly agree
# 854                                     Strongly agree
#
#     It was easy to talk to / connect with my advisor  \
# 850                                   Strongly agree
# 851                                   Strongly agree
# 852                                   Strongly agree
# 853                                   Strongly agree
# 854                                   Strongly agree
#
#     My overall evaluation of this advising meeting is  \
# 850                                         Excellent
# 851                                         Excellent
# 852                                         Excellent
# 853                                         Excellent
# 854                                         Excellent
#
#     My overall evaluation of this advisor is  \
# 850                                Excellent
# 851                                Excellent
# 852                                Excellent
# 853                                Excellent
# 854                                Excellent
#
#                                               Comments
# 850                                        No Response
# 851                                        No Response
# 852  I feel a sense of comfort when I’m meeting wit...
# 853                                        No Response
# 854                                        No Response

# %% [markdown]
# ## 3. Filter data for a single advisor

# %%
# filter data for a single advisor

# create dynamic list of advisors based on filtered month and year
# example test code: advisor_list = sorted(df['Advisor'].dropna().unique().tolist())

advisor = 'Marilou'
filtered_advisor = access_df[access_df['Advisor'].str.startswith(advisor)]

# %%
# check data
advisor
# Out:
# 'Marilou'

# %% [markdown]
# ## 4. Create summary for Likert scale responses

# %%
# list to store summary of scores for each question
# question_score = filtered_advisor.apply(pd.Series.value_counts).fillna(0).astype(int)
# print(question_score)
question_score = []

# get list of questions
questions = []
questions = filtered_advisor.columns[2:-1]
questions 

# get total number of responses
number_responses = len(filtered_advisor)
number_responses
# Out:
# 9

# %%
# check data
questions
# Out:
# Index(['I am more aware of the opportunities and options available to me',
#        'I am better able to select courses and evaluate my academic progress',
#        'I feel more confident about deciding my next steps',
#        'The advisor was informative and knowledgeable',
#        'The advisor was respectful and listened carefully to what I shared',
#        'I was satisfied with how my advisor handled my questions',
#        'It was easy to talk to my advisor',
#        'My overall evaluation of this advising appointment is',
#        'My overall evaluation of this advisor is'],
#       dtype='object')

# %%
# loop through questions and count scores
# loop 1: questions
# loop 2: scale
#    count = (df[question] == scale).sum()
#    percent = count / total * 100
#    display_count = f'{count}<br>{percent:.1f}%'  # combines count and percent into single value
#    summary.append({
#        'Question': question,
#        'Score': scale,
#        'Count': display_count
#    })

for i in questions:
    for j in likert_scale_access1:
        count = (filtered_advisor[i] == j).sum()
        percent = count / number_responses * 100
        display_count = f'{count}<br>{percent:.1f}%'
        question_score.append({
            'Question': i,
            'Score': j,
            'Count': display_count
        })

# %%
# check data
question_score
# Out:
# [{'Question': 'I am more aware of the opportunities and options available to me',
#   'Score': 'Strongly Agree (5)',
#   'Count': '9<br>100.0%'},
#  {'Question': 'I am more aware of the opportunities and options available to me',
#   'Score': 'Agree (4)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'I am more aware of the opportunities and options available to me',
#   'Score': 'Neutral (3)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'I am more aware of the opportunities and options available to me',
#   'Score': 'Disagree (2)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'I am more aware of the opportunities and options available to me',
#   'Score': 'Strongly Disagree (1)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'I am more aware of the opportunities and options available to me',
#   'Score': 'Not Applicable (0)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'I am more aware of the opportunities and options available to me',
#   'Score': 'No Response',
#   'Count': '0<br>0.0%'},
#  {'Question': 'I am better able to select courses and evaluate my academic progress',
#   'Score': 'Strongly Agree (5)',
#   'Count': '9<br>100.0%'},
#  {'Question': 'I am better able to select courses and evaluate my academic progress',
#   'Score': 'Agree (4)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'I am better able to select courses and evaluate my academic progress',
#   'Score': 'Neutral (3)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'I am better able to select courses and evaluate my academic progress',
#   'Score': 'Disagree (2)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'I am better able to select courses and evaluate my academic progress',
#   'Score': 'Strongly Disagree (1)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'I am better able to select courses and evaluate my academic progress',
#   'Score': 'Not Applicable (0)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'I am better able to select courses and evaluate my academic progress',
#   'Score': 'No Response',
#   'Count': '0<br>0.0%'},
#  {'Question': 'I feel more confident about deciding my next steps',
#   'Score': 'Strongly Agree (5)',
#   'Count': '8<br>88.9%'},
#  {'Question': 'I feel more confident about deciding my next steps',
#   'Score': 'Agree (4)',
#   'Count': '1<br>11.1%'},
#  {'Question': 'I feel more confident about deciding my next steps',
#   'Score': 'Neutral (3)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'I feel more confident about deciding my next steps',
#   'Score': 'Disagree (2)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'I feel more confident about deciding my next steps',
#   'Score': 'Strongly Disagree (1)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'I feel more confident about deciding my next steps',
#   'Score': 'Not Applicable (0)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'I feel more confident about deciding my next steps',
#   'Score': 'No Response',
#   'Count': '0<br>0.0%'},
#  {'Question': 'The advisor was informative and knowledgeable',
#   'Score': 'Strongly Agree (5)',
#   'Count': '8<br>88.9%'},
#  {'Question': 'The advisor was informative and knowledgeable',
#   'Score': 'Agree (4)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'The advisor was informative and knowledgeable',
#   'Score': 'Neutral (3)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'The advisor was informative and knowledgeable',
#   'Score': 'Disagree (2)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'The advisor was informative and knowledgeable',
#   'Score': 'Strongly Disagree (1)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'The advisor was informative and knowledgeable',
#   'Score': 'Not Applicable (0)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'The advisor was informative and knowledgeable',
#   'Score': 'No Response',
#   'Count': '1<br>11.1%'},
#  {'Question': 'The advisor was respectful and listened carefully to what I shared',
#   'Score': 'Strongly Agree (5)',
#   'Count': '8<br>88.9%'},
#  {'Question': 'The advisor was respectful and listened carefully to what I shared',
#   'Score': 'Agree (4)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'The advisor was respectful and listened carefully to what I shared',
#   'Score': 'Neutral (3)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'The advisor was respectful and listened carefully to what I shared',
#   'Score': 'Disagree (2)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'The advisor was respectful and listened carefully to what I shared',
#   'Score': 'Strongly Disagree (1)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'The advisor was respectful and listened carefully to what I shared',
#   'Score': 'Not Applicable (0)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'The advisor was respectful and listened carefully to what I shared',
#   'Score': 'No Response',
#   'Count': '1<br>11.1%'},
#  {'Question': 'I was satisfied with how my advisor handled my questions',
#   'Score': 'Strongly Agree (5)',
#   'Count': '9<br>100.0%'},
#  {'Question': 'I was satisfied with how my advisor handled my questions',
#   'Score': 'Agree (4)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'I was satisfied with how my advisor handled my questions',
#   'Score': 'Neutral (3)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'I was satisfied with how my advisor handled my questions',
#   'Score': 'Disagree (2)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'I was satisfied with how my advisor handled my questions',
#   'Score': 'Strongly Disagree (1)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'I was satisfied with how my advisor handled my questions',
#   'Score': 'Not Applicable (0)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'I was satisfied with how my advisor handled my questions',
#   'Score': 'No Response',
#   'Count': '0<br>0.0%'},
#  {'Question': 'It was easy to talk to my advisor',
#   'Score': 'Strongly Agree (5)',
#   'Count': '9<br>100.0%'},
#  {'Question': 'It was easy to talk to my advisor',
#   'Score': 'Agree (4)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'It was easy to talk to my advisor',
#   'Score': 'Neutral (3)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'It was easy to talk to my advisor',
#   'Score': 'Disagree (2)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'It was easy to talk to my advisor',
#   'Score': 'Strongly Disagree (1)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'It was easy to talk to my advisor',
#   'Score': 'Not Applicable (0)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'It was easy to talk to my advisor',
#   'Score': 'No Response',
#   'Count': '0<br>0.0%'},
#  {'Question': 'My overall evaluation of this advising appointment is',
#   'Score': 'Strongly Agree (5)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'My overall evaluation of this advising appointment is',
#   'Score': 'Agree (4)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'My overall evaluation of this advising appointment is',
#   'Score': 'Neutral (3)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'My overall evaluation of this advising appointment is',
#   'Score': 'Disagree (2)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'My overall evaluation of this advising appointment is',
#   'Score': 'Strongly Disagree (1)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'My overall evaluation of this advising appointment is',
#   'Score': 'Not Applicable (0)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'My overall evaluation of this advising appointment is',
#   'Score': 'No Response',
#   'Count': '0<br>0.0%'},
#  {'Question': 'My overall evaluation of this advisor is',
#   'Score': 'Strongly Agree (5)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'My overall evaluation of this advisor is',
#   'Score': 'Agree (4)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'My overall evaluation of this advisor is',
#   'Score': 'Neutral (3)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'My overall evaluation of this advisor is',
#   'Score': 'Disagree (2)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'My overall evaluation of this advisor is',
#   'Score': 'Strongly Disagree (1)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'My overall evaluation of this advisor is',
#   'Score': 'Not Applicable (0)',
#   'Count': '0<br>0.0%'},
#  {'Question': 'My overall evaluation of this advisor is',
#   'Score': 'No Response',
#   'Count': '0<br>0.0%'}]

# %% [markdown]
# **Pivot summary data**
#
# pandas.DataFrame.pivot (https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.pivot.html)

# %%
# convert to DataFrame
df = pd.DataFrame(question_score)

# pivot summary data
df = df.pivot(index='Question', columns='Score', values='Count')
#df = df.pivot(columns=['Question', 'Score'], values='Count')
df
# Out:
# Score                                                Agree (4) Disagree (2)  \
# Question
# I am better able to select courses and evaluate...   0<br>0.0%    0<br>0.0%
# I am more aware of the opportunities and option...   0<br>0.0%    0<br>0.0%
# I feel more confident about deciding my next steps  1<br>11.1%    0<br>0.0%
# I was satisfied with how my advisor handled my ...   0<br>0.0%    0<br>0.0%
# It was easy to talk to my advisor                    0<br>0.0%    0<br>0.0%
# My overall evaluation of this advising appointm...   0<br>0.0%    0<br>0.0%
# My overall evaluation of this advisor is             0<br>0.0%    0<br>0.0%
# The advisor was informative and knowledgeable        0<br>0.0%    0<br>0.0%
# The advisor was respectful and listened careful...   0<br>0.0%    0<br>0.0%
#
# Score                                              Neutral (3) No Response  \
# Question
# I am better able to select courses and evaluate...   0<br>0.0%   0<br>0.0%
# I am more aware of the opportunities and option...   0<br>0.0%   0<br>0.0%
# I feel more confident about deciding my next steps   0<br>0.0%   0<br>0.0%
# I was satisfied with how my advisor handled my ...   0<br>0.0%   0<br>0.0%
# It was easy to talk to my advisor                    0<br>0.0%   0<br>0.0%
# My overall evaluation of this advising appointm...   0<br>0.0%   0<br>0.0%
# My overall evaluation of this advisor is             0<br>0.0%   0<br>0.0%
# The advisor was informative and knowledgeable        0<br>0.0%  1<br>11.1%
# The advisor was respectful and listened careful...   0<br>0.0%  1<br>11.1%
#
# Score                                              Not Applicable (0)  \
# Question
# I am better able to select courses and evaluate...          0<br>0.0%
# I am more aware of the opportunities and option...          0<br>0.0%
# I feel more confident about deciding my next steps          0<br>0.0%
# I was satisfied with how my advisor handled my ...          0<br>0.0%
# It was easy to talk to my advisor                           0<br>0.0%
# My overall evaluation of this advising appointm...          0<br>0.0%
# My overall evaluation of this advisor is                    0<br>0.0%
# The advisor was informative and knowledgeable               0<br>0.0%
# The advisor was respectful and listened careful...          0<br>0.0%
#
# Score                                              Strongly Agree (5)  \
# Question
# I am better able to select courses and evaluate...        9<br>100.0%
# I am more aware of the opportunities and option...        9<br>100.0%
# I feel more confident about deciding my next steps         8<br>88.9%
# I was satisfied with how my advisor handled my ...        9<br>100.0%
# It was easy to talk to my advisor                         9<br>100.0%
# My overall evaluation of this advising appointm...          0<br>0.0%
# My overall evaluation of this advisor is                    0<br>0.0%
# The advisor was informative and knowledgeable              8<br>88.9%
# The advisor was respectful and listened careful...         8<br>88.9%
#
# Score                                              Strongly Disagree (1)
# Question
# I am better able to select courses and evaluate...             0<br>0.0%
# I am more aware of the opportunities and option...             0<br>0.0%
# I feel more confident about deciding my next steps             0<br>0.0%
# I was satisfied with how my advisor handled my ...             0<br>0.0%
# It was easy to talk to my advisor                              0<br>0.0%
# My overall evaluation of this advising appointm...             0<br>0.0%
# My overall evaluation of this advisor is                       0<br>0.0%
# The advisor was informative and knowledgeable                  0<br>0.0%
# The advisor was respectful and listened careful...             0<br>0.0%

# %%
# reorder columns
# df[scale].loc[questions]
df = df[likert_scale_access1].loc[questions]

# remove 'Score' label
# df.columns.name = None
df.columns.name = None

# %%
# check data
df
# Out:
#                                                    Strongly Agree (5)  \
# I am more aware of the opportunities and option...        9<br>100.0%
# I am better able to select courses and evaluate...        9<br>100.0%
# I feel more confident about deciding my next steps         8<br>88.9%
# The advisor was informative and knowledgeable              8<br>88.9%
# The advisor was respectful and listened careful...         8<br>88.9%
# I was satisfied with how my advisor handled my ...        9<br>100.0%
# It was easy to talk to my advisor                         9<br>100.0%
# My overall evaluation of this advising appointm...          0<br>0.0%
# My overall evaluation of this advisor is                    0<br>0.0%
#
#                                                      Agree (4) Neutral (3)  \
# I am more aware of the opportunities and option...   0<br>0.0%   0<br>0.0%
# I am better able to select courses and evaluate...   0<br>0.0%   0<br>0.0%
# I feel more confident about deciding my next steps  1<br>11.1%   0<br>0.0%
# The advisor was informative and knowledgeable        0<br>0.0%   0<br>0.0%
# The advisor was respectful and listened careful...   0<br>0.0%   0<br>0.0%
# I was satisfied with how my advisor handled my ...   0<br>0.0%   0<br>0.0%
# It was easy to talk to my advisor                    0<br>0.0%   0<br>0.0%
# My overall evaluation of this advising appointm...   0<br>0.0%   0<br>0.0%
# My overall evaluation of this advisor is             0<br>0.0%   0<br>0.0%
#
#                                                    Disagree (2)  \
# I am more aware of the opportunities and option...    0<br>0.0%
# I am better able to select courses and evaluate...    0<br>0.0%
# I feel more confident about deciding my next steps    0<br>0.0%
# The advisor was informative and knowledgeable         0<br>0.0%
# The advisor was respectful and listened careful...    0<br>0.0%
# I was satisfied with how my advisor handled my ...    0<br>0.0%
# It was easy to talk to my advisor                     0<br>0.0%
# My overall evaluation of this advising appointm...    0<br>0.0%
# My overall evaluation of this advisor is              0<br>0.0%
#
#                                                    Strongly Disagree (1)  \
# I am more aware of the opportunities and option...             0<br>0.0%
# I am better able to select courses and evaluate...             0<br>0.0%
# I feel more confident about deciding my next steps             0<br>0.0%
# The advisor was informative and knowledgeable                  0<br>0.0%
# The advisor was respectful and listened careful...             0<br>0.0%
# I was satisfied with how my advisor handled my ...             0<br>0.0%
# It was easy to talk to my advisor                              0<br>0.0%
# My overall evaluation of this advising appointm...             0<br>0.0%
# My overall evaluation of this advisor is                       0<br>0.0%
#
#                                                    Not Applicable (0)  \
# I am more aware of the opportunities and option...          0<br>0.0%
# I am better able to select courses and evaluate...          0<br>0.0%
# I feel more confident about deciding my next steps          0<br>0.0%
# The advisor was informative and knowledgeable               0<br>0.0%
# The advisor was respectful and listened careful...          0<br>0.0%
# I was satisfied with how my advisor handled my ...          0<br>0.0%
# It was easy to talk to my advisor                           0<br>0.0%
# My overall evaluation of this advising appointm...          0<br>0.0%
# My overall evaluation of this advisor is                    0<br>0.0%
#
#                                                    No Response
# I am more aware of the opportunities and option...   0<br>0.0%
# I am better able to select courses and evaluate...   0<br>0.0%
# I feel more confident about deciding my next steps   0<br>0.0%
# The advisor was informative and knowledgeable       1<br>11.1%
# The advisor was respectful and listened careful...  1<br>11.1%
# I was satisfied with how my advisor handled my ...   0<br>0.0%
# It was easy to talk to my advisor                    0<br>0.0%
# My overall evaluation of this advising appointm...   0<br>0.0%
# My overall evaluation of this advisor is             0<br>0.0%

# %% [markdown]
# **Convert to html table**
#
# pandas.DataFrame.to_html (https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_html.html)

# %%
# convert to html table

html_table = df.to_html()
print(html_table)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Strongly Agree (5)</th>
#       <th>Agree (4)</th>
#       <th>Neutral (3)</th>
#       <th>Disagree (2)</th>
#       <th>Strongly Disagree (1)</th>
#       <th>Not Applicable (0)</th>
#       <th>No Response</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>I am more aware of the opportunities and options available to me</th>
#       <td>9&lt;br&gt;100.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#     </tr>
#     <tr>
#       <th>I am better able to select courses and evaluate my academic progress</th>
#       <td>9&lt;br&gt;100.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#     </tr>
#     <tr>
#       <th>I feel more confident about deciding my next steps</th>
#       <td>8&lt;br&gt;88.9%</td>
#       <td>1&lt;br&gt;11.1%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#     </tr>
#     <tr>
#       <th>The advisor was informative and knowledgeable</th>
#       <td>8&lt;br&gt;88.9%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>1&lt;br&gt;11.1%</td>
#     </tr>
#     <tr>
#       <th>The advisor was respectful and listened carefully to what I shared</th>
#       <td>8&lt;br&gt;88.9%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>1&lt;br&gt;11.1%</td>
#     </tr>
#     <tr>
#       <th>I was satisfied with how my advisor handled my questions</th>
#       <td>9&lt;br&gt;100.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#     </tr>
#     <tr>
#       <th>It was easy to talk to my advisor</th>
#       <td>9&lt;br&gt;100.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#     </tr>
#     <tr>
#       <th>My overall evaluation of this advising appointment is</th>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#     </tr>
#     <tr>
#       <th>My overall evaluation of this advisor is</th>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#     </tr>
#   </tbody>
# </table>

# %%
# display html table
# display(HTML(html_table))
display(HTML(html_table))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Strongly Agree (5)</th>
#       <th>Agree (4)</th>
#       <th>Neutral (3)</th>
#       <th>Disagree (2)</th>
#       <th>Strongly Disagree (1)</th>
#       <th>Not Applicable (0)</th>
#       <th>No Response</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>I am more aware of the opportunities and options available to me</th>
#       <td>9&lt;br&gt;100.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#     </tr>
#     <tr>
#       <th>I am better able to select courses and evaluate my academic progress</th>
#       <td>9&lt;br&gt;100.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#     </tr>
#     <tr>
#       <th>I feel more confident about deciding my next steps</th>
#       <td>8&lt;br&gt;88.9%</td>
#       <td>1&lt;br&gt;11.1%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#     </tr>
#     <tr>
#       <th>The advisor was informative and knowledgeable</th>
#       <td>8&lt;br&gt;88.9%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>1&lt;br&gt;11.1%</td>
#     </tr>
#     <tr>
#       <th>The advisor was respectful and listened carefully to what I shared</th>
#       <td>8&lt;br&gt;88.9%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>1&lt;br&gt;11.1%</td>
#     </tr>
#     <tr>
#       <th>I was satisfied with how my advisor handled my questions</th>
#       <td>9&lt;br&gt;100.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#     </tr>
#     <tr>
#       <th>It was easy to talk to my advisor</th>
#       <td>9&lt;br&gt;100.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#     </tr>
#     <tr>
#       <th>My overall evaluation of this advising appointment is</th>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#     </tr>
#     <tr>
#       <th>My overall evaluation of this advisor is</th>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 5. Get comments

# %%
# get list of comments
comments = filtered_advisor.iloc[:, -1]

# exclude 'No Response"
comments = comments[comments != 'No Response']

# convert to dataframe
commentsdf = pd.DataFrame(comments)

# convert to html table
comments_html = commentsdf.to_html()

# set to empty string if there are no comments
print(len(comments_html))

if len(comments_html) < 1:
    comments_html = ''

comments_html
# Out:
# 1446
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Comments</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>6300</th>\n      <td>she was great and really really nice, 10/10 would go again!</td>\n    </tr>\n    <tr>\n      <th>6319</th>\n      <td>I specifically chose to go with this counselor after our first appointment because she was awesome! Extremely helpful doesn’t make me feel rushed and is truly there to help.</td>\n    </tr>\n    <tr>\n      <th>6322</th>\n      <td>Best experience I’ve had with an advisor! She was so patient and helpful, I got so much out of the short meeting and I will definitely be meeting with her again. 10/10 experience:)</td>\n    </tr>\n    <tr>\n      <th>6326</th>\n      <td>Thank you for meeting with me and giving me info as a real counselor and not because I met you for the first time you’re trying to figure me out. You didn’t discriminate my intelligence based on the way I looked. Not going to lie, I had to schedule with counselors that was the same race as me. Picking someone of your race, that doubted me in the beginning and you showing me true Ohana and kindness. Really made me feel good about the appointment. Thank you. You’re amazing and truly have good wisdom.</td>\n    </tr>\n    <tr>\n      <th>6334</th>\n      <td>I left the appointment more aware of all of the resources that are available to me.</td>\n    </tr>\n  </tbody>\n</table>'

# %%
# display html table
# display(HTML(html_table))

display(HTML(comments_html))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Comments</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6300</th>
#       <td>she was great and really really nice, 10/10 would go again!</td>
#     </tr>
#     <tr>
#       <th>6319</th>
#       <td>I specifically chose to go with this counselor after our first appointment because she was awesome! Extremely helpful doesn’t make me feel rushed and is truly there to help.</td>
#     </tr>
#     <tr>
#       <th>6322</th>
#       <td>Best experience I’ve had with an advisor! She was so patient and helpful, I got so much out of the short meeting and I will definitely be meeting with her again. 10/10 experience:)</td>
#     </tr>
#     <tr>
#       <th>6326</th>
#       <td>Thank you for meeting with me and giving me info as a real counselor and not because I met you for the first time you’re trying to figure me out. You didn’t discriminate my intelligence based on the way I looked. Not going to lie, I had to schedule with counselors that was the same race as me. Picking someone of your race, that doubted me in the beginning and you showing me true Ohana and kindness. Really made me feel good about the appointment. Thank you. You’re amazing and truly have good wisdom.</td>
#     </tr>
#     <tr>
#       <th>6334</th>
#       <td>I left the appointment more aware of all of the resources that are available to me.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 6. Split topics (comma-separated responses)

# %%
# list to store topics
soc_topics = []

# get responses
meeting = soc_df.columns[3]
responses = soc_df[meeting].values

responses

# split responses (use for loop))
for i in responses:
    
    # replace response that contains a comma
    i = i.replace('Major information, options', 'Major information/options')
    i = i.replace(', ', ',')
    
    # split values by comma
    split = i.split(',')
    
    # add topic to list
    for j in split:
        soc_topics.append(j)
    
# convert to dataframe
df = pd.DataFrame(soc_topics)

# create summary
summary = df.value_counts().reset_index()
summary = summary.rename(columns={0: 'Topics'})
summary

# convert to html table
html_topics = summary.to_html()

# add disclaimer at the bottom
html_topics = html_topics + '<p>One student can select more than one topic during a meeting.</p>'

html_topics
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Topics</th>\n      <th>count</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Academic Planning</td>\n      <td>4</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Registration Questions</td>\n      <td>4</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>Advice about a petition</td>\n      <td>1</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>BAM program for Economics</td>\n      <td>1</td>\n    </tr>\n    <tr>\n      <th>4</th>\n      <td>Career information</td>\n      <td>1</td>\n    </tr>\n    <tr>\n      <th>5</th>\n      <td>Graduation</td>\n      <td>1</td>\n    </tr>\n    <tr>\n      <th>6</th>\n      <td>Internships</td>\n      <td>1</td>\n    </tr>\n    <tr>\n      <th>7</th>\n      <td>Mandatory Advising</td>\n      <td>1</td>\n    </tr>\n  </tbody>\n</table><p>One student can select more than one topic during a meeting.</p>'

# %%
# list to store topics
#soc_topics = []

# get responses
#meeting = soc_df.columns[3]
#responses = soc_df[meeting].values

# split responses (use for loop))
#for index, row in soc_df_meeting.iterrows():
    
    # replace response that contains a comma
#    soc_df_meeting = soc_df_meeting.replace('Major information, options', 'Major information/options')
    
    # split values by comma
#    split = row['What did your meeting include?  Check all that apply'].split(',')
    
    # add topic to list
#    for s in split:
#        soc_topics.append(s)
    
# convert to dataframe
#soc_topics_df = pd.DataFrame(soc_topics)

#soc_topics_df = soc_topics_df.value_counts()
#soc_topics_df = soc_topics_df.to_frame()
#df.rename(columns={"A": "a", "B": "c"})
#soc_topics_df = soc_topics_df.rename(columns={0: 'Topics', 'count': 'Count(s)'})

# convert to html table
#html_topics = soc_topics_df.to_html()

# add disclaimer at the bottom
#html_topics = html_topics + '<p>One student can select more than one topic during a meeting.</p>'

#html_topics

# %%
# display html table
# display(HTML(html_table))
display(HTML(html_topics))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Topics</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Academic Planning</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Registration Questions</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Advice about a petition</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>BAM program for Economics</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Career information</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Graduation</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Internships</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Mandatory Advising</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table><p>One student can select more than one topic during a meeting.</p>

# %% [markdown]
# ## 7. Combine summary data (put html tables together)

# %%
# set header and pagebreak

header = '<h1>Monthly Evals for ' + advisor + '</h1>' + '<h5>Date: datevariable'+ '</h5>'

# combine header + html tables + pagebreak
body = header + html_topics + html_table + comments_html

# create full html page
page = '<html><head><title>Monthly Evals</title><meta charset="utf-8"><meta name="viewport" content="width=device-width, initial-scale=1"></head><body>'
page = page + body + '</body></html>'

# save as html file
display(HTML(page))
# Out:
# <html><head><title>Monthly Evals</title><meta charset="utf-8"><meta name="viewport" content="width=device-width, initial-scale=1"></head><body><h1>Monthly Evals for Marilou</h1><h5>Date: datevariable</h5><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Topics</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Academic Planning</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Registration Questions</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Advice about a petition</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>BAM program for Economics</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Career information</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Graduation</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Internships</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Mandatory Advising</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table><p>One student can select more than one topic during a meeting.</p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Strongly Agree (5)</th>
#       <th>Agree (4)</th>
#       <th>Neutral (3)</th>
#       <th>Disagree (2)</th>
#       <th>Strongly Disagree (1)</th>
#       <th>Not Applicable (0)</th>
#       <th>No Response</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>I am more aware of the opportunities and options available to me</th>
#       <td>9&lt;br&gt;100.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#     </tr>
#     <tr>
#       <th>I am better able to select courses and evaluate my academic progress</th>
#       <td>9&lt;br&gt;100.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#     </tr>
#     <tr>
#       <th>I feel more confident about deciding my next steps</th>
#       <td>8&lt;br&gt;88.9%</td>
#       <td>1&lt;br&gt;11.1%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#     </tr>
#     <tr>
#       <th>The advisor was informative and knowledgeable</th>
#       <td>8&lt;br&gt;88.9%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>1&lt;br&gt;11.1%</td>
#     </tr>
#     <tr>
#       <th>The advisor was respectful and listened carefully to what I shared</th>
#       <td>8&lt;br&gt;88.9%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>1&lt;br&gt;11.1%</td>
#     </tr>
#     <tr>
#       <th>I was satisfied with how my advisor handled my questions</th>
#       <td>9&lt;br&gt;100.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#     </tr>
#     <tr>
#       <th>It was easy to talk to my advisor</th>
#       <td>9&lt;br&gt;100.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#     </tr>
#     <tr>
#       <th>My overall evaluation of this advising appointment is</th>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#     </tr>
#     <tr>
#       <th>My overall evaluation of this advisor is</th>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#       <td>0&lt;br&gt;0.0%</td>
#     </tr>
#   </tbody>
# </table><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Comments</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6300</th>
#       <td>she was great and really really nice, 10/10 would go again!</td>
#     </tr>
#     <tr>
#       <th>6319</th>
#       <td>I specifically chose to go with this counselor after our first appointment because she was awesome! Extremely helpful doesn’t make me feel rushed and is truly there to help.</td>
#     </tr>
#     <tr>
#       <th>6322</th>
#       <td>Best experience I’ve had with an advisor! She was so patient and helpful, I got so much out of the short meeting and I will definitely be meeting with her again. 10/10 experience:)</td>
#     </tr>
#     <tr>
#       <th>6326</th>
#       <td>Thank you for meeting with me and giving me info as a real counselor and not because I met you for the first time you’re trying to figure me out. You didn’t discriminate my intelligence based on the way I looked. Not going to lie, I had to schedule with counselors that was the same race as me. Picking someone of your race, that doubted me in the beginning and you showing me true Ohana and kindness. Really made me feel good about the appointment. Thank you. You’re amazing and truly have good wisdom.</td>
#     </tr>
#     <tr>
#       <th>6334</th>
#       <td>I left the appointment more aware of all of the resources that are available to me.</td>
#     </tr>
#   </tbody>
# </table></body></html>

# %% [markdown]
# ## ✨ Congratulations on finishing the really hard part!
